# %%
a=10

# %%
print(id(a))
# Out:
# 4352224128

# %%
b=10

# %%
print(id(b))
# Out:
# 4352224128

# %%
a,b,c=10,20,30,40
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 a,b,c=10,20,30,40
#
# ValueError: too many values to unpack (expected 3)

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
c
# Out:
# 30

# %%
x=10
y=10.0

# %%
print(id(x))
# Out:
# 4352224128

# %%
print(id(y))
# Out:
# 4379928560

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(y))
# Out:
# <class 'float'>

# %%
x=10 
print(id(x))
x=x+1 
print(id(x))
# Out:
# 4352224128
# 4352224160

# %%
x=[1,2]
print(id(x))
print(x)
print("After modification")
x.append(3)
print(id(x))
print(x)
# Out:
# 4398732736
# [1, 2]
# After modification
# 4398732736
# [1, 2, 3]

# %%
x=10
y=10000
print(id(x),id(y))
# Out:
# 4352224128 4398812688

# %%
x=10
y=10
print(id(x),id(y))
# Out:
# 4352224128 4352224128

# %%
x=100
y=100
print(id(x),id(y))
# Out:
# 4352227008 4352227008

# %%
x=300
y=300
print(id(x),id(y))
# Out:
# 4398811728 4398811984

# %%
print(0.1+0.2)
# Out:
# 0.30000000000000004
